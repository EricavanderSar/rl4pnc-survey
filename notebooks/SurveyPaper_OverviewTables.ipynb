# %%
import os
import numpy as np
import matplotlib
import pandas as pd
import json
import argparse
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import scienceplots

# %%
path = "/Users/ericavandersar/surfdrive/Documents/Research/Results_SurveyPaper"

file_name_summ_data = "summarized_data.csv"
file_name_boxplot_data = "boxplot_data.csv"

df_RLbaselines = pd.read_csv(os.path.join(path, file_name_summ_data))
df_RLbaselines = df_RLbaselines.sort_values(['opponent', 'action space',], ascending=[True, True])
df_RLbaselines
# Out:
#    agent_type                         agent_id  opponent  train_opponent  \
# 0   CustomPPO  CustomPPO_old_env_8858963_b869f     False           False
# 4   CustomPPO  CustomPPO_old_env_8858964_bbfa5     False           False
# 5   CustomPPO  CustomPPO_old_env_8858965_c1b05     False           False
# 9   CustomPPO  CustomPPO_old_env_8858961_bdec6     False           False
# 11  CustomPPO  CustomPPO_old_env_8858966_c1b05     False           False
# 1   CustomPPO  CustomPPO_old_env_8773703_13880     False           False
# 3   CustomPPO  CustomPPO_old_env_8773704_13fc9     False           False
# 8   CustomPPO  CustomPPO_old_env_8773705_13c89     False           False
# 10  CustomPPO  CustomPPO_old_env_8773702_1357a     False           False
# 2   CustomPPO  CustomPPO_old_env_8858956_41da2     False           False
# 6   CustomPPO  CustomPPO_old_env_8858955_41d7e     False           False
# 7   CustomPPO  CustomPPO_old_env_8858954_41d3f     False           False
# 12  CustomPPO  CustomPPO_old_env_8858963_b869f      True           False
# 16  CustomPPO  CustomPPO_old_env_8858964_bbfa5      True           False
# 21  CustomPPO  CustomPPO_old_env_8858961_bdec6      True           False
# 24  CustomPPO  CustomPPO_old_env_8858966_c1b05      True           False
# 13  CustomPPO  CustomPPO_old_env_8773703_13880      True           False
# 15  CustomPPO  CustomPPO_old_env_8773704_13fc9      True           False
# 20  CustomPPO  CustomPPO_old_env_8773705_13c89      True           False
# 23  CustomPPO  CustomPPO_old_env_8773702_1357a      True           False
# 25  CustomPPO  CustomPPO_old_env_8773678_08f9b      True           False
# 14  CustomPPO  CustomPPO_old_env_8858956_41da2      True           False
# 17  CustomPPO  CustomPPO_old_env_8858955_41d7e      True           False
# 18  CustomPPO  CustomPPO_old_env_8858954_41d3f      True           False
# 19  CustomPPO  CustomPPO_old_env_8858953_3de5a      True           False
# 22  CustomPPO  CustomPPO_old_env_8858957_41da4      True           False
#
#    action space              observation space    AT  line_reco  line_disc  \
# 0         assym  ['p_i', 'p_l', 'r', 'o', 'd']  0.95       True      False
# 4         assym  ['p_i', 'p_l', 'r', 'o', 'd']  0.95       True      False
# 5         assym  ['p_i', 'p_l', 'r', 'o', 'd']  0.95       True      False
# 9         assym  ['p_i', 'p_l', 'r', 'o', 'd']  0.95       True      False
# 11        assym  ['p_i', 'p_l', 'r', 'o', 'd']  0.95       True      False
# 1         medha  ['p_i', 'p_l', 'r', 'o', 'd']  0.95       True      False
# 3         medha  ['p_i', 'p_l', 'r', 'o', 'd']  0.95       True      False
# 8         medha  ['p_i', 'p_l', 'r', 'o', 'd']  0.95       True      False
# 10        medha  ['p_i', 'p_l', 'r', 'o', 'd']  0.95       True      False
# 2        tennet  ['p_i', 'p_l', 'r', 'o', 'd']  0.95       True      False
# 6        tennet  ['p_i', 'p_l', 'r', 'o', 'd']  0.95       True      False
# 7        tennet  ['p_i', 'p_l', 'r', 'o', 'd']  0.95       True      False
# 12        assym  ['p_i', 'p_l', 'r', 'o', 'd']  0.95       True      False
# 16        assym  ['p_i', 'p_l', 'r', 'o', 'd']  0.95       True      False
# 21        assym  ['p_i', 'p_l', 'r', 'o', 'd']  0.95       True      False
# 24        assym  ['p_i', 'p_l', 'r', 'o', 'd']  0.95       True      False
# 13        medha  ['p_i', 'p_l', 'r', 'o', 'd']  0.95       True      False
# 15        medha  ['p_i', 'p_l', 'r', 'o', 'd']  0.95       True      False
# 20        medha  ['p_i', 'p_l', 'r', 'o', 'd']  0.95       True      False
# 23        medha  ['p_i', 'p_l', 'r', 'o', 'd']  0.95       True      False
# 25        medha  ['p_i', 'p_l', 'r', 'o', 'd']  0.95       True      False
# 14       tennet  ['p_i', 'p_l', 'r', 'o', 'd']  0.95       True      False
# 17       tennet  ['p_i', 'p_l', 'r', 'o', 'd']  0.95       True      False
# 18       tennet  ['p_i', 'p_l', 'r', 'o', 'd']  0.95       True      False
# 19       tennet  ['p_i', 'p_l', 'r', 'o', 'd']  0.95       True      False
# 22       tennet  ['p_i', 'p_l', 'r', 'o', 'd']  0.95       True      False
#
#     reset_topo  ... train reset_topo  steps survived  steps overloaded  \
# 0          0.0  ...                0           85.01             0.010
# 4          0.0  ...                0           83.36             0.037
# 5          0.0  ...                0           84.78             0.013
# 9          0.0  ...                0           81.30             0.025
# 11         0.0  ...                0           85.41             0.008
# 1          0.0  ...                0           90.21             0.011
# 3          0.0  ...                0           88.96             0.008
# 8          0.0  ...                0           87.50             0.010
# 10         0.0  ...                0           76.97             0.018
# 2          0.0  ...                0           84.41             0.030
# 6          0.0  ...                0           85.22             0.038
# 7          0.0  ...                0           78.48             0.016
# 12         0.0  ...                0            4.84             0.530
# 16         0.0  ...                0            4.58             0.655
# 21         0.0  ...                0            4.26             0.777
# 24         0.0  ...                0            4.42             0.648
# 13         0.0  ...                0            4.82             0.622
# 15         0.0  ...                0            4.19             0.965
# 20         0.0  ...                0            4.41             0.649
# 23         0.0  ...                0            4.57             0.842
# 25         0.0  ...                0            4.58             0.682
# 14         0.0  ...                0            4.57             2.189
# 17         0.0  ...                0            4.37             2.515
# 18         0.0  ...                0            4.40             2.865
# 19         0.0  ...                0            4.45             2.037
# 22         0.0  ...                0            4.68             1.943
#
#     execution time [ms]  agent execution time [ms]  maximum topology depth  \
# 0                 0.132                      2.189                       5
# 4                 0.150                      2.561                       5
# 5                 0.151                      2.231                       5
# 9                 0.143                      3.391                       5
# 11                0.132                      2.232                       5
# 1                 0.133                      2.224                       5
# 3                 0.130                      2.232                       5
# 8                 0.130                      2.216                       4
# 10                0.132                      2.135                       5
# 2                 0.134                      1.952                       4
# 6                 0.133                      2.085                       4
# 7                 0.134                      2.013                       4
# 12                0.650                      2.375                       3
# 16                0.678                      2.976                       3
# 21                0.817                      2.419                       4
# 24                0.660                      2.263                       3
# 13                0.686                      3.075                       3
# 15                0.662                      2.185                       4
# 20                0.761                      2.467                       3
# 23                0.644                      2.213                       3
# 25                0.699                      2.284                       3
# 14                0.668                      2.140                       3
# 17                0.762                      2.082                       4
# 18                0.687                      1.958                       3
# 19                0.684                      2.664                       4
# 22                0.730                      2.230                       4
#
#     unique actions  unique lines in danger  unqique subs changed  \
# 0               36                      11                    11
# 4               37                      12                    10
# 5               35                      12                     9
# 9               44                      17                    11
# 11              34                      14                     9
# 1               27                      12                     7
# 3               35                      11                     5
# 8               26                      13                     5
# 10              47                      14                     7
# 2               28                      15                     5
# 6               24                      16                     4
# 7               10                       8                     5
# 12              11                      11                     8
# 16               7                      12                     5
# 21              17                      12                     9
# 24              10                      12                     7
# 13               8                      11                     6
# 15              15                      12                     5
# 20              13                      14                     6
# 23              10                       9                     4
# 25               9                      12                     4
# 14              15                      14                     5
# 17              25                      15                     5
# 18              13                      14                     5
# 19              24                      16                     5
# 22              34                      16                     5
#
#                    substations changed
# 0   [ 8  3  4  2  5 13  1  6 11 10 12]
# 4      [ 3  8  1  4 10  5  9 12 13  6]
# 5         [ 8  3  4  1  5  6 12  0  9]
# 9   [ 3  8  4  1  6  5 13  0  2 11 12]
# 11        [ 3  8  4  2  5  1 11  6 12]
# 1               [ 8  3  4  1 12  5  2]
# 3                          [1 4 8 3 5]
# 8                          [8 3 4 1 5]
# 10              [ 3  8  2  4  5  1 12]
# 2                          [1 3 5 4 8]
# 6                            [1 4 3 5]
# 7                          [3 1 4 8 5]
# 12           [ 8  3  4  2 10  6  9  5]
# 16                    [ 3  8  1 12  5]
# 21        [ 8  3  1  4 11  2  5 13  0]
# 24              [ 8  3  4  1  5 12  2]
# 13                 [ 8  3  4  1 12  5]
# 15                         [8 1 3 4 5]
# 20                 [ 8  4  3 12  1  5]
# 23                           [8 3 4 2]
# 25                           [8 3 1 5]
# 14                         [5 3 1 4 8]
# 17                         [3 1 4 5 8]
# 18                         [4 3 1 8 5]
# 19                         [4 3 5 1 8]
# 22                         [3 1 4 5 8]
#
# [26 rows x 24 columns]

# %%
df_RLbaselines[df_RLbaselines["agent_id"]=="CustomPPO_old_env_8893043_86a8c"]
# Out:
# Empty DataFrame
# Columns: [agent_type, agent_id, opponent, train_opponent, action space, observation space, AT, line_reco, line_disc, reset_topo, train reward, train AT, train line_reco, train line_disc, train reset_topo, steps survived, steps overloaded, execution time [ms], agent execution time [ms], maximum topology depth, unique actions, unique lines in danger, unqique subs changed, substations changed]
# Index: []
#
# [0 rows x 24 columns]

# %%
heur_path = os.path.join(path, "Greedy_DN")
df_heur = pd.read_csv(os.path.join(heur_path, file_name_summ_data))
df_heur = df_heur.sort_values(['opponent', 'action space',], ascending=[True, True])
df_heur
# Out:
#    agent_type agent_id  opponent  train_opponent action space  \
# 0   DoNothing      xxx     False           False        medha
# 1   DoNothing      xxx     False           False        medha
# 2   DoNothing      xxx     False           False        medha
# 3   DoNothing      xxx     False           False        medha
# 4   RhoGreedy      xxx     False           False        medha
# 6   RhoGreedy      xxx     False           False        medha
# 9   RhoGreedy      xxx     False           False        medha
# 11  RhoGreedy      xxx     False           False        medha
# 12  RhoGreedy      xxx     False           False        medha
# 14  RhoGreedy      xxx     False           False        medha
# 17  RhoGreedy      xxx     False           False        medha
# 18  RhoGreedy      xxx     False           False        medha
# 5   RhoGreedy      xxx     False           False       tennet
# 7   RhoGreedy      xxx     False           False       tennet
# 8   RhoGreedy      xxx     False           False       tennet
# 10  RhoGreedy      xxx     False           False       tennet
# 13  RhoGreedy      xxx     False           False       tennet
# 15  RhoGreedy      xxx     False           False       tennet
# 16  RhoGreedy      xxx     False           False       tennet
# 19  RhoGreedy      xxx     False           False       tennet
# 20  DoNothing      xxx      True           False        medha
# 21  DoNothing      xxx      True           False        medha
# 22  DoNothing      xxx      True           False        medha
# 23  DoNothing      xxx      True           False        medha
# 25  RhoGreedy      xxx      True           False        medha
# 27  RhoGreedy      xxx      True           False        medha
# 29  RhoGreedy      xxx      True           False        medha
# 30  RhoGreedy      xxx      True           False        medha
# 33  RhoGreedy      xxx      True           False        medha
# 34  RhoGreedy      xxx      True           False        medha
# 37  RhoGreedy      xxx      True           False        medha
# 38  RhoGreedy      xxx      True           False        medha
# 24  RhoGreedy      xxx      True           False       tennet
# 26  RhoGreedy      xxx      True           False       tennet
# 28  RhoGreedy      xxx      True           False       tennet
# 31  RhoGreedy      xxx      True           False       tennet
# 32  RhoGreedy      xxx      True           False       tennet
# 35  RhoGreedy      xxx      True           False       tennet
# 36  RhoGreedy      xxx      True           False       tennet
# 39  RhoGreedy      xxx      True           False       tennet
#
#     observation space    AT  line_reco  line_disc  reset_topo  ...  \
# 0                 NaN  0.95      False      False         2.0  ...
# 1                 NaN  0.95      False       True         2.0  ...
# 2                 NaN  0.95       True      False         2.0  ...
# 3                 NaN  0.95       True       True         2.0  ...
# 4                 NaN  0.95      False      False         2.0  ...
# 6                 NaN  0.95      False      False         0.8  ...
# 9                 NaN  0.95      False       True         2.0  ...
# 11                NaN  0.95      False       True         0.8  ...
# 12                NaN  0.95       True      False         2.0  ...
# 14                NaN  0.95       True      False         0.8  ...
# 17                NaN  0.95       True       True         2.0  ...
# 18                NaN  0.95       True       True         0.8  ...
# 5                 NaN  0.95      False      False         2.0  ...
# 7                 NaN  0.95      False      False         0.8  ...
# 8                 NaN  0.95      False       True         2.0  ...
# 10                NaN  0.95      False       True         0.8  ...
# 13                NaN  0.95       True      False         2.0  ...
# 15                NaN  0.95       True      False         0.8  ...
# 16                NaN  0.95       True       True         2.0  ...
# 19                NaN  0.95       True       True         0.8  ...
# 20                NaN  0.95      False      False         2.0  ...
# 21                NaN  0.95      False       True         2.0  ...
# 22                NaN  0.95       True      False         2.0  ...
# 23                NaN  0.95       True       True         2.0  ...
# 25                NaN  0.95      False      False         2.0  ...
# 27                NaN  0.95      False      False         0.8  ...
# 29                NaN  0.95      False       True         2.0  ...
# 30                NaN  0.95      False       True         0.8  ...
# 33                NaN  0.95       True      False         2.0  ...
# 34                NaN  0.95       True      False         0.8  ...
# 37                NaN  0.95       True       True         2.0  ...
# 38                NaN  0.95       True       True         0.8  ...
# 24                NaN  0.95      False      False         2.0  ...
# 26                NaN  0.95      False      False         0.8  ...
# 28                NaN  0.95      False       True         2.0  ...
# 31                NaN  0.95      False       True         0.8  ...
# 32                NaN  0.95       True      False         2.0  ...
# 35                NaN  0.95       True      False         0.8  ...
# 36                NaN  0.95       True       True         2.0  ...
# 39                NaN  0.95       True       True         0.8  ...
#
#    train reset_topo  steps survived  steps overloaded  execution time [ms]  \
# 0                 0           20.90             0.185                0.064
# 1                 0           19.46             0.154                0.078
# 2                 0           20.90             0.185                0.074
# 3                 0           19.46             0.154                0.090
# 4                 0          100.00             0.013                0.864
# 6                 0          100.00             0.006                4.455
# 9                 0          100.00             0.013                0.879
# 11                0          100.00             0.006                4.555
# 12                0          100.00             0.014                0.870
# 14                0          100.00             0.006                4.464
# 17                0          100.00             0.014                0.885
# 18                0          100.00             0.006                4.438
# 5                 0           96.37             0.070                1.742
# 7                 0           95.20             0.063                5.733
# 8                 0           92.02             0.035                1.679
# 10                0           91.87             0.026                5.422
# 13                0           99.74             0.022                0.890
# 15                0           99.91             0.011                4.837
# 16                0           99.20             0.026                0.911
# 19                0           99.78             0.012                4.942
# 20                0            1.92             4.137                0.065
# 21                0            1.82             4.417                0.111
# 22                0            4.59             1.337                0.140
# 23                0            5.17             2.039                0.224
# 25                0            4.67             1.490               37.444
# 27                0            6.88             1.422               41.199
# 29                0            4.84             0.848               35.933
# 30                0            7.13             0.550               41.229
# 33                0            9.03             1.217               29.594
# 34                0            8.89             1.384               38.234
# 37                0            7.39             0.744               44.047
# 38                0            7.66             0.818               42.444
# 24                0            4.56             2.621               23.129
# 26                0            7.40             2.143               33.179
# 28                0            4.75             1.361               26.205
# 31                0            7.06             1.011               24.872
# 32                0            9.33             1.691               23.153
# 35                0           10.48             1.570               27.726
# 36                0            7.48             0.971               29.604
# 39                0            8.00             0.864               23.871
#
#     agent execution time [ms]  maximum topology depth  unique actions  \
# 0                       0.063                       1               1
# 1                       0.077                       1               1
# 2                       0.073                       1               1
# 3                       0.089                       1               1
# 4                     368.298                       5              66
# 6                     375.330                       5              51
# 9                     370.531                       5              66
# 11                    382.306                       5              51
# 12                    369.669                       5              65
# 14                    374.968                       5              51
# 17                    371.918                       5              65
# 18                    372.116                       5              51
# 5                     205.754                       5              55
# 7                     204.355                       5              52
# 8                     204.533                       5              54
# 10                    204.564                       5              52
# 13                    210.361                       5              52
# 15                    208.826                       5              49
# 16                    211.915                       5              53
# 19                    213.246                       5              49
# 20                      0.062                       1               1
# 21                      0.143                       1               1
# 22                      0.241                       1               1
# 23                      1.144                       1               1
# 25                    368.653                       5              79
# 27                    366.913                       5              87
# 29                    357.556                       5              81
# 30                    364.148                       5              73
# 33                    365.313                       5              88
# 34                    368.080                       6              81
# 37                    357.301                       5              80
# 38                    373.295                       5              71
# 24                    200.013                       5              55
# 26                    208.644                       5              56
# 28                    203.086                       5              55
# 31                    204.933                       5              55
# 32                    208.128                       5              54
# 35                    212.446                       5              58
# 36                    208.692                       5              51
# 39                    207.851                       5              54
#
#     unique lines in danger  unqique subs changed  substations changed
# 0                        4                     0                   []
# 1                        4                     0                   []
# 2                        4                     0                   []
# 3                        4                     0                   []
# 4                       10                     6  [ 8  3  4  1  5 12]
# 6                       11                     5          [8 3 4 1 5]
# 9                       10                     6  [ 8  3  4  1  5 12]
# 11                      11                     5          [8 3 4 1 5]
# 12                      12                     5          [8 3 4 1 5]
# 14                      11                     5          [8 3 4 1 5]
# 17                      12                     5          [8 3 4 1 5]
# 18                      11                     5          [8 3 4 1 5]
# 5                       17                     5          [4 1 3 8 5]
# 7                       17                     5          [4 1 3 8 5]
# 8                       17                     5          [4 1 3 8 5]
# 10                      17                     5          [4 1 3 8 5]
# 13                      16                     5          [4 1 3 8 5]
# 15                      14                     5          [4 1 3 8 5]
# 16                      17                     5          [4 1 3 8 5]
# 19                      17                     5          [4 1 3 8 5]
# 20                      12                     0                   []
# 21                      12                     0                   []
# 22                      12                     0                   []
# 23                      11                     0                   []
# 25                      15                     6  [ 1  8  4  3  5 12]
# 27                      17                     6  [ 3  8  4  1  5 12]
# 29                      15                     6  [ 1  4  5  3  8 12]
# 30                      14                     6  [ 4  8  1 12  3  5]
# 33                      14                     5          [5 4 8 1 3]
# 34                      17                     6  [ 5  8  4  3  1 12]
# 37                      15                     6  [ 5  8  4  3  1 12]
# 38                      15                     5          [1 4 8 3 5]
# 24                      16                     5          [1 4 8 3 5]
# 26                      16                     5          [3 1 4 5 8]
# 28                      15                     5          [4 3 8 1 5]
# 31                      17                     5          [4 8 5 3 1]
# 32                      17                     5          [1 3 4 8 5]
# 35                      16                     5          [4 1 3 5 8]
# 36                      16                     5          [4 8 3 1 5]
# 39                      18                     5          [3 8 5 4 1]
#
# [40 rows x 24 columns]

# %%
measures = ['agent_type', 
            'opponent', 
            # 'action space', 
            'steps survived', 
            'steps overloaded', 
            'agent execution time [ms]',
            'maximum topology depth',
            'unique actions',
            'unique lines in danger',
            'unqique subs changed',
            'substations changed'
           ]
filter_dn_base = ((df_heur['agent_type'] == "DoNothing") & ~(df_heur['line_reco']) & ~(df_heur['line_disc']))
filter_greedy_base = ((df_heur['agent_type'] == "RhoGreedy") & (df_heur['action space'] == "medha") & (df_heur['line_reco']) & ~(df_heur['line_disc']) & (df_heur['reset_topo']!=2.0) )
df_heur.loc[(filter_dn_base | filter_greedy_base), measures]
# Out:
#    agent_type  opponent  steps survived  steps overloaded  \
# 0   DoNothing     False           20.90             0.185
# 14  RhoGreedy     False          100.00             0.006
# 20  DoNothing      True            1.92             4.137
# 34  RhoGreedy      True            8.89             1.384
#
#     agent execution time [ms]  maximum topology depth  unique actions  \
# 0                       0.063                       1               1
# 14                    374.968                       5              51
# 20                      0.062                       1               1
# 34                    368.080                       6              81
#
#     unique lines in danger  unqique subs changed  substations changed
# 0                        4                     0                   []
# 14                      11                     5          [8 3 4 1 5]
# 20                      12                     0                   []
# 34                      17                     6  [ 5  8  4  3  1 12]
